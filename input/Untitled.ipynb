# %%
import pandas as pd

# %%
df = pd.read_csv('countrycurrency.csv')

# %%
dfA = pd.read_csv('airport.csv')

# %%
dfA.HEA.describe()
# Out:
# count     5836
# unique    5834
# top        ZYA
# freq         2
# Name: HEA, dtype: object

# %%
dfA
# Out:
#       2048                        Herat               Herat.1  \
# 0     2049                    Jalalabad             Jalalabad
# 1     2050                   Kabul Intl                 Kabul
# 2     2051                     Kandahar              Kandahar
# 3     2052                      Maimana               Maimama
# 4     2053               Mazar I Sharif        Mazar-i-sharif
# 5     2056                       Konduz                Kunduz
# 6     5922             Faizabad Airport              Faizabad
# 7     7036                   Bagram AFB                 Kabul
# 8     7499           Tarin Kowt Airport            Tarin Kowt
# 9     7500               Zaranj Airport                Zaranj
# 10    7501          Chaghcharan Airport           Chaghcharan
# 11    8127                  FOB Salerno                 Khost
# 12    8146                      Sharona               Sharona
# 13    8773                 Bost Airport           Lashkar Gah
# ...
